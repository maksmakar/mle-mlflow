# %%
import os
import psycopg 
import pandas as pd
from dotenv import load_dotenv, find_dotenv
from sqlalchemy import create_engine

# %%
# подгружаем .env
load_dotenv()
# Out:
# True

# %%
# Считываем все креды
src_host = os.environ.get('DB_SOURCE_HOST')
src_port = os.environ.get('DB_SOURCE_PORT')
src_username = os.environ.get('DB_SOURCE_USER')
src_password = os.environ.get('DB_SOURCE_PASSWORD')
src_db = os.environ.get('DB_SOURCE_NAME') 

dst_host = os.environ.get('DB_DESTINATION_HOST')
dst_port = os.environ.get('DB_DESTINATION_PORT')
dst_username = os.environ.get('DB_DESTINATION_USER')
dst_password = os.environ.get('DB_DESTINATION_PASSWORD')
dst_db = os.environ.get('DB_DESTINATION_NAME')

s3_bucket = os.environ.get('S3_BUCKET_NAME')
s3_access_key = os.environ.get('AWS_ACCESS_KEY_ID')
s3_secret_access_key = os.environ.get('AWS_SECRET_ACCESS_KEY')

# %%
import boto3
import botocore

# Указываем эндпоинт и ключи доступа
s3 = boto3.client(
    's3',
    endpoint_url="https://storage.yandexcloud.net",
    aws_access_key_id=s3_access_key, # Ваш Access Key
    aws_secret_access_key=s3_secret_access_key, 
    config=botocore.client.Config(signature_version='s3v4'),  # Используем правильную конфигурацию
)

# Укажите имя бакета
bucket_name = "s3-student-mle-20250130-582c662a4e"

# Получите список объектов в бакете
try:
    response = s3.list_objects_v2(Bucket=bucket_name)
    
    # Проверьте, есть ли объекты в бакете
    if 'Contents' in response:
        print(f"Файлы в бакете {bucket_name}:")
        for obj in response['Contents']:
            print(f"- {obj['Key']} (размер: {obj['Size']} байт)")
    else:
        print(f"Бакет {bucket_name} пуст.")
except Exception as e:
    print(f"Ошибка при получении списка объектов: {e}")
# Out:
# Файлы в бакете s3-student-mle-20250130-582c662a4e:
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/MLmodel (размер: 803 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/code/fit.py (размер: 2022 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/conda.yaml (размер: 415 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/input_example.json (размер: 382 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/model.cb (размер: 1070936 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/python_env.yaml (размер: 115 байт)
# - 7/268f18d996e04bef998053cea95bbe22/artifacts/models/requirements.txt (размер: 257 байт)
# - 7/fcb9527584ad40d0a202075d7119372d/artifacts/dataframe/columns.txt (размер: 273 байт)
# - 7/fcb9527584ad40d0a202075d7119372d/artifacts/dataframe/users_churn.csv (размер: 865601 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/MLmodel (размер: 803 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/code/fit.py (размер: 2022 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/conda.yaml (размер: 415 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/input_example.json (размер: 382 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/model.cb (размер: 1070936 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/python_env.yaml (размер: 115 байт)
# - 7/ff7ac48789254ec28f845102ba1379ae/artifacts/models/requirements.txt (размер: 257 байт)
# - cv_results/cv_res.json (размер: 77 байт)
# - data/initial_data.csv (размер: 822095 байт)
# - models/fitted_model.pkl (размер: 1084799 байт)
# - part2_dvc/cv_results/cv_res.json (размер: 113 байт)
# - part2_dvc/data/initial_data.csv (размер: 12407646 байт)
# - part2_dvc/models/fitted_model.pkl (размер: 1115298 байт)

# %%
import mlflow

# определяем основные credentials, которые нужны для подключения к MLflow
# важно, что credentials мы передаём для себя как пользователей Tracking Service
# у вас должен быть доступ к бакету, в который вы будете складывать артефакты
os.environ["MLFLOW_S3_ENDPOINT_URL"] = "https://storage.yandexcloud.net" #endpoint бакета от YandexCloud
os.environ["AWS_ACCESS_KEY_ID"] = os.getenv("AWS_ACCESS_KEY_ID") # получаем id ключа бакета, к которому подключён MLFlow, из .env
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv("AWS_SECRET_ACCESS_KEY") # получаем ключ бакета, к которому подключён MLFlow, из .env

# определяем глобальные переменные
# поднимаем MLflow локально
TRACKING_SERVER_HOST = "127.0.0.1"
TRACKING_SERVER_PORT = 5000

YOUR_NAME = "test_exp" # введите своё имя для создания уникального эксперимента
assert YOUR_NAME, "введите своё имя в переменной YOUR_NAME для создания уникального эксперимента"

# название тестового эксперимента и запуска (run) внутри него
EXPERIMENT_NAME = f"test_connection_experiment_{YOUR_NAME}"
RUN_NAME = "test_connection_run"

# тестовые данные
METRIC_NAME = "test_metric"
METRIC_VALUE = 0

# устанавливаем host, который будет отслеживать наши эксперименты
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}")

# создаём тестовый эксперимент и записываем в него тестовую информацию
#experiment_id = mlflow.create_experiment(EXPERIMENT_NAME)
#with mlflow.start_run(run_name=RUN_NAME, experiment_id=experiment_id) as run:
#    run_id = run.info.run_id
#    
#    mlflow.log_metric(METRIC_NAME, METRIC_VALUE)

# %%
connection = {"sslmode": "require", "target_session_attrs": "read-write"}
postgres_credentials = {
    "host": "rc1b-uh7kdmcx67eomesf.mdb.yandexcloud.net", 
    "port": "6432",
    "dbname": "playground_mle_20250130_582c662a4e",
    "user": "mle_20250130_582c662a4e",
    "password": "31992be741c54a3f85a88b4082cdcad7",
}
assert all([var_value != "" for var_value in list(postgres_credentials.values())])

connection.update(postgres_credentials)

# определим название таблицы, в которой хранятся наши данные.
TABLE_NAME = "users_churn"

# эта конструкция создаёт контекстное управление для соединения с базой данных 
# оператор with гарантирует, что соединение будет корректно закрыто после выполнения всех операций 
# закрыто оно будет даже в случае ошибки, чтобы не допустить "утечку памяти"
with psycopg.connect(**connection) as conn:

# создаёт объект курсора для выполнения запросов к базе данных
# с помощью метода execute() выполняется SQL-запрос для выборки данных из таблицы TABLE_NAME
    with conn.cursor() as cur:
        cur.execute(f"SELECT * FROM {TABLE_NAME}")
                
                # извлекаем все строки, полученные в результате выполнения запроса
        data = cur.fetchall()

                # получает список имён столбцов из объекта курсора
        columns = [col[0] for col in cur.description]

# создаёт объект DataFrame из полученных данных и имён столбцов. 
# это позволяет удобно работать с данными в Python, используя библиотеку Pandas.
df = pd.DataFrame(data, columns=columns)

# %%
import json
# 1. Название колонок вашего датафрейма запишите в текстовый файл
with open("columns.txt", "w", encoding="utf-8") as fio:
    fio.write(",".join(df.columns))
    
metrics = {
    "num_rows": len(df),
    "num_columns": len(df.columns),
}

with open("metrics.json", "w", encoding="utf-8") as f:
    json.dump(metrics, f, indent=4)
    
df.to_csv("dataset.csv", index=False)

# %%
counts_columns = [
    "type", "paperless_billing", "internet_service", "online_security", "online_backup", "device_protection",
    "tech_support", "streaming_tv", "streaming_movies", "gender", "senior_citizen", "partner", "dependents",
    "multiple_lines", "target"
]

stats = {}

for col in counts_columns:
    # Посчитать количество уникальных значений в колонке
    column_stat = df[col].value_counts().to_dict()
    column_stat = {f"{col}_{key}": value for key, value in column_stat.items()}

    # Обновить словарь stats
    stats.update(column_stat)

# Общая длина данных
stats["data_length"] = df.shape[0]

# Статистики по monthly_charges
stats["monthly_charges_min"] = df["monthly_charges"].min()
stats["monthly_charges_max"] = df["monthly_charges"].max()
stats["monthly_charges_mean"] = df["monthly_charges"].mean()
stats["monthly_charges_median"] = df["monthly_charges"].median()

# Статистики по total_charges
stats["total_charges_min"] = df["total_charges"].min()
stats["total_charges_max"] = df["total_charges"].max()
stats["total_charges_mean"] = df["total_charges"].mean()
stats["total_charges_median"] = df["total_charges"].median()

# Количество уникальных пользователей
stats["unique_customers_number"] = df["customer_id"].nunique()

# Количество пропусков в end_date
stats["end_date_nan"] = df["end_date"].isna().sum()

# %%
import mlflow
import os
import json

# задаём название эксперимента и имя запуска для логирования в MLflow
EXPERIMENT_NAME = "churn_fio_new"
RUN_NAME = "data_check"

# создаём новый эксперимент в MLflow с указанным названием 
# если эксперимент с таким именем уже существует, 
# MLflow возвращает идентификатор существующего эксперимента
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
if experiment is None:
    experiment_id = mlflow.create_experiment(EXPERIMENT_NAME)
else:
    experiment_id = experiment.experiment_id

# Проверка наличия файлов перед логированием и их создание, если их нет
columns_file_path = "columns.txt"
dataset_file_path = 'users_churn.csv'

# Проверка на существование файла и его создание
if not os.path.exists(columns_file_path):
    with open(columns_file_path, "w", encoding="utf-8") as f:
        f.write(",".join(df.columns))

if not os.path.exists(dataset_file_path):
    df.to_csv(dataset_file_path, index=False)

# Убедимся, что файлы существуют
assert os.path.exists(columns_file_path), f"{columns_file_path} does not exist."
assert os.path.exists(dataset_file_path), f"{dataset_file_path} does not exist."

# Начинаем логирование, передавая experiment_id
with mlflow.start_run(experiment_id=experiment_id, run_name=RUN_NAME) as run:
    run_id = run.info.run_id  # Получаем уникальный ID запуска
    
    # Логируем метрики
    mlflow.log_metrics(stats)

    # Логируем файлы как артефакты эксперимента, передавая абсолютный путь
    mlflow.log_artifact('columns.txt', artifact_path="dataframe")
    mlflow.log_artifact('users_churn.csv', artifact_path="dataframe")

# Получаем информацию о запуске
run = mlflow.get_run(run_id)

# Проверяем статус завершённого эксперимента
assert run.info.status == "FINISHED"

# Удаляем файлы после логирования
os.remove(columns_file_path)
os.remove(dataset_file_path)

# %% [markdown]
# ### Логируем модель

# %%
# EXPERIMENT_NAME = "churn_fio_new"

# experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

# if experiment:
#     experiment_id = experiment.experiment_id
#     experiment_name = experiment.name
#     run_count = len(mlflow.search_runs(experiment_ids=[experiment_id]))
    
#     print(f"experiment_id = {experiment_id}")
#     print(f"experiment_name = '{experiment_name}'")
#     print(f"run_count = {run_count}")

# %% [markdown]
# Подгружаем нашу модель

# %%
# Укажите путь к файлу
import joblib

# Загружаем модель
with open('../churn_model/fitted_model.pkl', 'rb') as fd:
    fit_pipeline = joblib.load(fd)

model = fit_pipeline.named_steps['model']

# %% [markdown]
# И теперь подгружаем наши данные для обучения

# %%
dst_conn = create_engine(f'postgresql://{dst_username}:{dst_password}@{dst_host}:{dst_port}/{dst_db}')

table = 'clean_users_churn'
churn = pd.read_sql(f'select * from {table}', dst_conn)

target = churn['target']

# %%
# Получаем наши признаки и скоры (входные и выходные данные)
transformed_data = fit_pipeline.named_steps['preprocessor'].transform(churn)
proba = model.predict_proba(transformed_data)[:, 1]

# %% [markdown]
# Логируем 1-ю версию модели

# %%
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score

# %%
import mlflow
import numpy as np

# Настройка подключения к tracking и registry
TRACKING_SERVER_HOST = "127.0.0.1"
TRACKING_SERVER_PORT = 5000
os.environ["MLFLOW_S3_ENDPOINT_URL"] = "https://storage.yandexcloud.net"

mlflow.set_tracking_uri(f'http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}')
mlflow.set_registry_uri(f'http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}')

EXPERIMENT_NAME = "churn_mmakarov"
RUN_NAME = "m0"
REGISTRY_MODEL_NAME = "churn_model_mmakarov"

# Создаём или получаем эксперимент
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
if experiment is None:
    experiment_id = mlflow.create_experiment(EXPERIMENT_NAME)
else:
    experiment_id = experiment.experiment_id

# Путь до файла с зависимостями pip
pip_requirements = "../requirements.txt"

# Формирование сигнатуры модели (входы и выходы)
signature = mlflow.models.infer_signature(
    transformed_data,
    proba
)

# Пример входных данных для модели
input_example = [transformed_data[0], transformed_data[1]] 

# Пути до скрипта с обучением модели
code_paths = ["../churn_model/fit.py"]

# Предположим, что модель уже обучена или инициализирована (в данном примере используем модель CatBoost)

with mlflow.start_run(run_name=RUN_NAME, experiment_id=experiment_id) as run:
    run_id = run.info.run_id

    # Логирование модели с передачей всех необходимых параметров и регистрация в реестре
    # model_info = mlflow.pyfunc.log_model(
    #     artifact_path="models",  # Путь для артефактов в реестре
    #     cb_model=model,  # Передаем модель CatBoost с параметром cb_model
    #     pip_requirements=pip_requirements,
    #     signature=signature,
    #     input_example=input_example,
    #     code_paths=code_paths,
    #     registered_model_name=REGISTRY_MODEL_NAME
    # )

    # Логируем метрики (например, точность на обучающих данных)
    roc_auc = roc_auc_score(target, proba)
    precision = precision_score(target, model.predict(transformed_data))
    recall = recall_score(target, model.predict(transformed_data))
    f1 = f1_score(target, model.predict(transformed_data))

    mlflow.log_metric("roc_auc", roc_auc)
    mlflow.log_metric("precision", precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)


    model_info = mlflow.catboost.log_model(
        cb_model=model,  # Передаем модель CatBoost
        artifact_path="models",  # Путь для артефактов в реестре
        pip_requirements=pip_requirements,
        signature=signature,
        input_example=input_example,
        code_paths=code_paths,
        registered_model_name=REGISTRY_MODEL_NAME
    )

    print(f"Model registered at: {model_info.model_uri}")
# Out:
# Successfully registered model 'churn_model_mmakarov'.
# 2025/03/15 11:52:42 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: churn_model_mmakarov, version 1
# Model registered at: runs:/e0bf6d32c34d4695b560b2bae1296ed7/models
# Created version '1' of model 'churn_model_mmakarov'.

# %%
from catboost import CatBoostClassifier

# %%
import mlflow
import numpy as np

# Настройка подключения к tracking и registry
TRACKING_SERVER_HOST = "127.0.0.1"
TRACKING_SERVER_PORT = 5000
os.environ["MLFLOW_S3_ENDPOINT_URL"] = "https://storage.yandexcloud.net"

mlflow.set_tracking_uri(f'http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}')
mlflow.set_registry_uri(f'http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}')

EXPERIMENT_NAME = "churn_mmakarov"
RUN_NAME = "m1"
REGISTRY_MODEL_NAME = "churn_model_mmakarov"

# Создаём или получаем эксперимент
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)
if experiment is None:
    experiment_id = mlflow.create_experiment(EXPERIMENT_NAME)
else:
    experiment_id = experiment.experiment_id

model_new = CatBoostClassifier(depth=5, iterations=1001)
model_new.fit(transformed_data, target)

# Путь до файла с зависимостями pip
pip_requirements = "../requirements.txt"

# Формирование сигнатуры модели (входы и выходы)
signature = mlflow.models.infer_signature(
    transformed_data,
    proba
)

# Пример входных данных для модели
input_example = [transformed_data[0], transformed_data[1]] 

# Пути до скрипта с обучением модели
code_paths = ["../churn_model/fit.py"]

# Предположим, что модель уже обучена или инициализирована (в данном примере используем модель CatBoost)

with mlflow.start_run(run_name=RUN_NAME, experiment_id=experiment_id) as run:
    run_id = run.info.run_id

    # Логирование модели с передачей всех необходимых параметров и регистрация в реестре
    # model_info = mlflow.pyfunc.log_model(
    #     artifact_path="models",  # Путь для артефактов в реестре
    #     cb_model=model,  # Передаем модель CatBoost с параметром cb_model
    #     pip_requirements=pip_requirements,
    #     signature=signature,
    #     input_example=input_example,
    #     code_paths=code_paths,
    #     registered_model_name=REGISTRY_MODEL_NAME
    # )

    # Логируем метрики (например, точность на обучающих данных)
    roc_auc = roc_auc_score(target, model_new.predict_proba(transformed_data)[:, 1])
    precision = precision_score(target, model_new.predict(transformed_data))
    recall = recall_score(target, model_new.predict(transformed_data))
    f1 = f1_score(target, model_new.predict(transformed_data))

    mlflow.log_metric("roc_auc", roc_auc)
    mlflow.log_metric("precision", precision)
    mlflow.log_metric("recall", recall)
    mlflow.log_metric("f1_score", f1)


    model_info = mlflow.catboost.log_model(
        cb_model=model,  # Передаем модель CatBoost
        artifact_path="models",  # Путь для артефактов в реестре
        pip_requirements=pip_requirements,
        signature=signature,
        input_example=input_example,
        code_paths=code_paths,
        registered_model_name=REGISTRY_MODEL_NAME
    )

    print(f"Model registered at: {model_info.model_uri}")
# Out:
# Learning rate set to 0.023654
# 0:	learn: 0.6790975	total: 2.48ms	remaining: 2.48s
# 1:	learn: 0.6648788	total: 4.94ms	remaining: 2.47s
# 2:	learn: 0.6516560	total: 8.04ms	remaining: 2.67s
# 3:	learn: 0.6378380	total: 10.6ms	remaining: 2.64s
# 4:	learn: 0.6249411	total: 12.9ms	remaining: 2.57s
# 5:	learn: 0.6137442	total: 15.3ms	remaining: 2.54s
# 6:	learn: 0.6041292	total: 19.6ms	remaining: 2.78s
# 7:	learn: 0.5944306	total: 22.3ms	remaining: 2.77s
# 8:	learn: 0.5849254	total: 25ms	remaining: 2.75s
# 9:	learn: 0.5761062	total: 27.5ms	remaining: 2.72s
# 10:	learn: 0.5684946	total: 29.9ms	remaining: 2.69s
# 11:	learn: 0.5610197	total: 32.2ms	remaining: 2.65s
# 12:	learn: 0.5526794	total: 34.5ms	remaining: 2.62s
# 13:	learn: 0.5470833	total: 36.9ms	remaining: 2.6s
# 14:	learn: 0.5407747	total: 39.6ms	remaining: 2.6s
# 15:	learn: 0.5338307	total: 42.9ms	remaining: 2.64s
# 16:	learn: 0.5297786	total: 44.7ms	remaining: 2.59s
# 17:	learn: 0.5239302	total: 47.6ms	remaining: 2.6s
# 18:	learn: 0.5190328	total: 50.1ms	remaining: 2.59s
# 19:	learn: 0.5133043	total: 52.9ms	remaining: 2.6s
# 20:	learn: 0.5087746	total: 55.6ms	remaining: 2.59s
# 21:	learn: 0.5044176	total: 58.1ms	remaining: 2.58s
# 22:	learn: 0.4997444	total: 62.3ms	remaining: 2.65s
# 23:	learn: 0.4963382	total: 64.7ms	remaining: 2.63s
# 24:	learn: 0.4931016	total: 67.8ms	remaining: 2.65s
# 25:	learn: 0.4894982	total: 70.6ms	remaining: 2.65s
# 26:	learn: 0.4867309	total: 73ms	remaining: 2.63s
# 27:	learn: 0.4835233	total: 75.3ms	remaining: 2.62s
# 28:	learn: 0.4802090	total: 77.6ms	remaining: 2.6s
# 29:	learn: 0.4776956	total: 79.9ms	remaining: 2.59s
# 30:	learn: 0.4744065	total: 82.3ms	remaining: 2.57s
# 31:	learn: 0.4718166	total: 85.6ms	remaining: 2.59s
# 32:	learn: 0.4692234	total: 88ms	remaining: 2.58s
# 33:	learn: 0.4666017	total: 90.5ms	remaining: 2.57s
# 34:	learn: 0.4644554	total: 93ms	remaining: 2.56s
# 35:	learn: 0.4624805	total: 95.2ms	remaining: 2.55s
# 36:	learn: 0.4605992	total: 97.4ms	remaining: 2.54s
# 37:	learn: 0.4590115	total: 99.6ms	remaining: 2.52s
# 38:	learn: 0.4572921	total: 102ms	remaining: 2.51s
# 39:	learn: 0.4556947	total: 104ms	remaining: 2.5s
# 40:	learn: 0.4538275	total: 106ms	remaining: 2.49s
# 41:	learn: 0.4521033	total: 109ms	remaining: 2.49s
# 42:	learn: 0.4505073	total: 111ms	remaining: 2.48s
# 43:	learn: 0.4489412	total: 114ms	remaining: 2.47s
# 44:	learn: 0.4474766	total: 116ms	remaining: 2.46s
# 45:	learn: 0.4463044	total: 118ms	remaining: 2.46s
# 46:	learn: 0.4451853	total: 121ms	remaining: 2.45s
# 47:	learn: 0.4441092	total: 123ms	remaining: 2.44s
# 48:	learn: 0.4428331	total: 125ms	remaining: 2.44s
# 49:	learn: 0.4416868	total: 128ms	remaining: 2.43s
# 50:	learn: 0.4405503	total: 130ms	remaining: 2.42s
# 51:	learn: 0.4397623	total: 133ms	remaining: 2.43s
# 52:	learn: 0.4387815	total: 136ms	remaining: 2.43s
# 53:	learn: 0.4372823	total: 138ms	remaining: 2.42s
# 54:	learn: 0.4365832	total: 140ms	remaining: 2.41s
# 55:	learn: 0.4354872	total: 143ms	remaining: 2.41s
# 56:	learn: 0.4346684	total: 145ms	remaining: 2.4s
# 57:	learn: 0.4339795	total: 148ms	remaining: 2.4s
# 58:	learn: 0.4330705	total: 150ms	remaining: 2.39s
# 59:	learn: 0.4324643	total: 153ms	remaining: 2.4s
# 60:	learn: 0.4314392	total: 155ms	remaining: 2.4s
# 61:	learn: 0.4304738	total: 158ms	remaining: 2.39s
# 62:	learn: 0.4297258	total: 160ms	remaining: 2.38s
# 63:	learn: 0.4292170	total: 162ms	remaining: 2.38s
# 64:	learn: 0.4283934	total: 165ms	remaining: 2.38s
# 65:	learn: 0.4276906	total: 170ms	remaining: 2.41s
# 66:	learn: 0.4270740	total: 173ms	remaining: 2.41s
# 67:	learn: 0.4265724	total: 175ms	remaining: 2.4s
# 68:	learn: 0.4259475	total: 177ms	remaining: 2.39s
# 69:	learn: 0.4253929	total: 180ms	remaining: 2.39s
# 70:	learn: 0.4249392	total: 184ms	remaining: 2.4s
# 71:	learn: 0.4243056	total: 186ms	remaining: 2.4s
# 72:	learn: 0.4238505	total: 188ms	remaining: 2.38s
# 73:	learn: 0.4233849	total: 190ms	remaining: 2.38s
# 74:	learn: 0.4228651	total: 194ms	remaining: 2.39s
# 75:	learn: 0.4224630	total: 196ms	remaining: 2.39s
# 76:	learn: 0.4219978	total: 198ms	remaining: 2.38s
# 77:	learn: 0.4214445	total: 200ms	remaining: 2.37s
# 78:	learn: 0.4208384	total: 202ms	remaining: 2.36s
# 79:	learn: 0.4204682	total: 206ms	remaining: 2.37s
# 80:	learn: 0.4200420	total: 209ms	remaining: 2.37s
# 81:	learn: 0.4195732	total: 212ms	remaining: 2.37s
# 82:	learn: 0.4192436	total: 214ms	remaining: 2.37s
# 83:	learn: 0.4188823	total: 216ms	remaining: 2.36s
# 84:	learn: 0.4185583	total: 220ms	remaining: 2.37s
# 85:	learn: 0.4180574	total: 222ms	remaining: 2.37s
# 86:	learn: 0.4177021	total: 226ms	remaining: 2.38s
# 87:	learn: 0.4173750	total: 229ms	remaining: 2.37s
# 88:	learn: 0.4169637	total: 231ms	remaining: 2.36s
# 89:	learn: 0.4166024	total: 233ms	remaining: 2.36s
# 90:	learn: 0.4162756	total: 236ms	remaining: 2.36s
# 91:	learn: 0.4159131	total: 238ms	remaining: 2.35s
# 92:	learn: 0.4155170	total: 240ms	remaining: 2.35s
# 93:	learn: 0.4151468	total: 243ms	remaining: 2.34s
# 94:	learn: 0.4148272	total: 245ms	remaining: 2.34s
# 95:	learn: 0.4144877	total: 247ms	remaining: 2.33s
# 96:	learn: 0.4140208	total: 250ms	remaining: 2.33s
# 97:	learn: 0.4137679	total: 252ms	remaining: 2.32s
# 98:	learn: 0.4135294	total: 255ms	remaining: 2.32s
# 99:	learn: 0.4133633	total: 257ms	remaining: 2.31s
# 100:	learn: 0.4131134	total: 259ms	remaining: 2.31s
# 101:	learn: 0.4128267	total: 262ms	remaining: 2.31s
# 102:	learn: 0.4125357	total: 264ms	remaining: 2.3s
# 103:	learn: 0.4122299	total: 266ms	remaining: 2.3s
# 104:	learn: 0.4120284	total: 269ms	remaining: 2.29s
# 105:	learn: 0.4117821	total: 271ms	remaining: 2.29s
# 106:	learn: 0.4115424	total: 273ms	remaining: 2.28s
# 107:	learn: 0.4112912	total: 276ms	remaining: 2.28s
# 108:	learn: 0.4111148	total: 278ms	remaining: 2.27s
# 109:	learn: 0.4108503	total: 280ms	remaining: 2.27s
# 110:	learn: 0.4106254	total: 282ms	remaining: 2.26s
# 111:	learn: 0.4105054	total: 285ms	remaining: 2.26s
# 112:	learn: 0.4102342	total: 288ms	remaining: 2.26s
# 113:	learn: 0.4099571	total: 290ms	remaining: 2.26s
# 114:	learn: 0.4097542	total: 293ms	remaining: 2.26s
# 115:	learn: 0.4095697	total: 296ms	remaining: 2.26s
# 116:	learn: 0.4093514	total: 299ms	remaining: 2.26s
# 117:	learn: 0.4091279	total: 301ms	remaining: 2.25s
# 118:	learn: 0.4089279	total: 303ms	remaining: 2.25s
# 119:	learn: 0.4087074	total: 305ms	remaining: 2.24s
# 120:	learn: 0.4085444	total: 307ms	remaining: 2.23s
# 121:	learn: 0.4083392	total: 310ms	remaining: 2.23s
# 122:	learn: 0.4081881	total: 312ms	remaining: 2.23s
# 123:	learn: 0.4079782	total: 314ms	remaining: 2.22s
# 124:	learn: 0.4077630	total: 317ms	remaining: 2.22s
# 125:	learn: 0.4076124	total: 319ms	remaining: 2.21s
# 126:	learn: 0.4073836	total: 321ms	remaining: 2.21s
# 127:	learn: 0.4071402	total: 324ms	remaining: 2.21s
# 128:	learn: 0.4070341	total: 326ms	remaining: 2.2s
# 129:	learn: 0.4068341	total: 328ms	remaining: 2.2s
# 130:	learn: 0.4066271	total: 331ms	remaining: 2.2s
# 131:	learn: 0.4064345	total: 334ms	remaining: 2.2s
# 132:	learn: 0.4062093	total: 336ms	remaining: 2.19s
# 133:	learn: 0.4060328	total: 339ms	remaining: 2.19s
# 134:	learn: 0.4058677	total: 341ms	remaining: 2.19s
# 135:	learn: 0.4057309	total: 343ms	remaining: 2.18s
# 136:	learn: 0.4055952	total: 346ms	remaining: 2.18s
# 137:	learn: 0.4054417	total: 348ms	remaining: 2.18s
# 138:	learn: 0.4052517	total: 351ms	remaining: 2.17s
# 139:	learn: 0.4050738	total: 353ms	remaining: 2.17s
# 140:	learn: 0.4049023	total: 355ms	remaining: 2.17s
# 141:	learn: 0.4047643	total: 358ms	remaining: 2.16s
# 142:	learn: 0.4046490	total: 360ms	remaining: 2.16s
# 143:	learn: 0.4044952	total: 362ms	remaining: 2.15s
# 144:	learn: 0.4042737	total: 365ms	remaining: 2.15s
# 145:	learn: 0.4041685	total: 367ms	remaining: 2.15s
# 146:	learn: 0.4040418	total: 369ms	remaining: 2.14s
# 147:	learn: 0.4038628	total: 372ms	remaining: 2.14s
# 148:	learn: 0.4036505	total: 376ms	remaining: 2.15s
# 149:	learn: 0.4035090	total: 378ms	remaining: 2.14s
# 150:	learn: 0.4033890	total: 380ms	remaining: 2.14s
# 151:	learn: 0.4032754	total: 382ms	remaining: 2.13s
# 152:	learn: 0.4031508	total: 384ms	remaining: 2.13s
# 153:	learn: 0.4030312	total: 386ms	remaining: 2.13s
# 154:	learn: 0.4028608	total: 390ms	remaining: 2.13s
# 155:	learn: 0.4027028	total: 392ms	remaining: 2.12s
# 156:	learn: 0.4025550	total: 394ms	remaining: 2.12s
# 157:	learn: 0.4024151	total: 397ms	remaining: 2.12s
# 158:	learn: 0.4023076	total: 399ms	remaining: 2.11s
# 159:	learn: 0.4021676	total: 402ms	remaining: 2.11s
# 160:	learn: 0.4020124	total: 404ms	remaining: 2.11s
# 161:	learn: 0.4018914	total: 407ms	remaining: 2.11s
# 162:	learn: 0.4017413	total: 409ms	remaining: 2.1s
# 163:	learn: 0.4016287	total: 411ms	remaining: 2.1s
# 164:	learn: 0.4014798	total: 414ms	remaining: 2.1s
# 165:	learn: 0.4013954	total: 416ms	remaining: 2.09s
# 166:	learn: 0.4012538	total: 418ms	remaining: 2.09s
# 167:	learn: 0.4011675	total: 420ms	remaining: 2.08s
# 168:	learn: 0.4010612	total: 423ms	remaining: 2.08s
# 169:	learn: 0.4009363	total: 425ms	remaining: 2.08s
# 170:	learn: 0.4008263	total: 428ms	remaining: 2.08s
# 171:	learn: 0.4007420	total: 430ms	remaining: 2.07s
# 172:	learn: 0.4005855	total: 433ms	remaining: 2.07s
# 173:	learn: 0.4005691	total: 434ms	remaining: 2.06s
# 174:	learn: 0.4004797	total: 437ms	remaining: 2.06s
# 175:	learn: 0.4002863	total: 439ms	remaining: 2.06s
# 176:	learn: 0.4001194	total: 441ms	remaining: 2.05s
# 177:	learn: 0.4000123	total: 446ms	remaining: 2.06s
# 178:	learn: 0.3999252	total: 450ms	remaining: 2.06s
# 179:	learn: 0.3998602	total: 454ms	remaining: 2.07s
# 180:	learn: 0.3997421	total: 457ms	remaining: 2.07s
# 181:	learn: 0.3996260	total: 461ms	remaining: 2.07s
# 182:	learn: 0.3995058	total: 463ms	remaining: 2.07s
# 183:	learn: 0.3994107	total: 465ms	remaining: 2.06s
# 184:	learn: 0.3992501	total: 467ms	remaining: 2.06s
# 185:	learn: 0.3991014	total: 470ms	remaining: 2.06s
# 186:	learn: 0.3990137	total: 473ms	remaining: 2.06s
# 187:	learn: 0.3989033	total: 476ms	remaining: 2.06s
# 188:	learn: 0.3988674	total: 478ms	remaining: 2.05s
# 189:	learn: 0.3987338	total: 480ms	remaining: 2.05s
# 190:	learn: 0.3986100	total: 483ms	remaining: 2.05s
# 191:	learn: 0.3985247	total: 486ms	remaining: 2.05s
# 192:	learn: 0.3983873	total: 488ms	remaining: 2.04s
# 193:	learn: 0.3982833	total: 490ms	remaining: 2.04s
# 194:	learn: 0.3981672	total: 493ms	remaining: 2.04s
# 195:	learn: 0.3980719	total: 495ms	remaining: 2.03s
# 196:	learn: 0.3979787	total: 498ms	remaining: 2.03s
# 197:	learn: 0.3979278	total: 500ms	remaining: 2.03s
# 198:	learn: 0.3978168	total: 502ms	remaining: 2.02s
# 199:	learn: 0.3977389	total: 505ms	remaining: 2.02s
# 200:	learn: 0.3976706	total: 507ms	remaining: 2.02s
# 201:	learn: 0.3975465	total: 510ms	remaining: 2.02s
# 202:	learn: 0.3974051	total: 513ms	remaining: 2.02s
# 203:	learn: 0.3973381	total: 515ms	remaining: 2.01s
# 204:	learn: 0.3971984	total: 518ms	remaining: 2.01s
# 205:	learn: 0.3971189	total: 520ms	remaining: 2.01s
# 206:	learn: 0.3970391	total: 522ms	remaining: 2s
# 207:	learn: 0.3969533	total: 525ms	remaining: 2s
# 208:	learn: 0.3968941	total: 527ms	remaining: 2s
# 209:	learn: 0.3968194	total: 530ms	remaining: 2s
# 210:	learn: 0.3967056	total: 532ms	remaining: 1.99s
# 211:	learn: 0.3965440	total: 535ms	remaining: 1.99s
# 212:	learn: 0.3964232	total: 537ms	remaining: 1.99s
# 213:	learn: 0.3963254	total: 540ms	remaining: 1.98s
# 214:	learn: 0.3962397	total: 543ms	remaining: 1.98s
# 215:	learn: 0.3961513	total: 545ms	remaining: 1.98s
# 216:	learn: 0.3960202	total: 549ms	remaining: 1.98s
# 217:	learn: 0.3959009	total: 551ms	remaining: 1.98s
# 218:	learn: 0.3957780	total: 553ms	remaining: 1.98s
# 219:	learn: 0.3957013	total: 556ms	remaining: 1.97s
# 220:	learn: 0.3955333	total: 558ms	remaining: 1.97s
# 221:	learn: 0.3954297	total: 560ms	remaining: 1.97s
# 222:	learn: 0.3953163	total: 563ms	remaining: 1.96s
# 223:	learn: 0.3952229	total: 565ms	remaining: 1.96s
# 224:	learn: 0.3950941	total: 567ms	remaining: 1.96s
# 225:	learn: 0.3949563	total: 570ms	remaining: 1.95s
# 226:	learn: 0.3948437	total: 572ms	remaining: 1.95s
# 227:	learn: 0.3947407	total: 575ms	remaining: 1.95s
# 228:	learn: 0.3946458	total: 578ms	remaining: 1.95s
# 229:	learn: 0.3945676	total: 580ms	remaining: 1.94s
# 230:	learn: 0.3944806	total: 582ms	remaining: 1.94s
# 231:	learn: 0.3943827	total: 587ms	remaining: 1.94s
# 232:	learn: 0.3942959	total: 589ms	remaining: 1.94s
# 233:	learn: 0.3942023	total: 591ms	remaining: 1.94s
# 234:	learn: 0.3941012	total: 594ms	remaining: 1.94s
# 235:	learn: 0.3940110	total: 596ms	remaining: 1.93s
# 236:	learn: 0.3939046	total: 599ms	remaining: 1.93s
# 237:	learn: 0.3938316	total: 601ms	remaining: 1.93s
# 238:	learn: 0.3937324	total: 604ms	remaining: 1.92s
# 239:	learn: 0.3936106	total: 606ms	remaining: 1.92s
# 240:	learn: 0.3935385	total: 608ms	remaining: 1.92s
# 241:	learn: 0.3934044	total: 611ms	remaining: 1.92s
# 242:	learn: 0.3932989	total: 613ms	remaining: 1.91s
# 243:	learn: 0.3931908	total: 615ms	remaining: 1.91s
# 244:	learn: 0.3931235	total: 618ms	remaining: 1.91s
# 245:	learn: 0.3930195	total: 620ms	remaining: 1.9s
# 246:	learn: 0.3929571	total: 623ms	remaining: 1.9s
# 247:	learn: 0.3928876	total: 625ms	remaining: 1.9s
# 248:	learn: 0.3928139	total: 627ms	remaining: 1.89s
# 249:	learn: 0.3927615	total: 630ms	remaining: 1.89s
# 250:	learn: 0.3927421	total: 632ms	remaining: 1.89s
# 251:	learn: 0.3926877	total: 634ms	remaining: 1.89s
# 252:	learn: 0.3925844	total: 637ms	remaining: 1.88s
# 253:	learn: 0.3925182	total: 639ms	remaining: 1.88s
# 254:	learn: 0.3923983	total: 641ms	remaining: 1.88s
# 255:	learn: 0.3923255	total: 645ms	remaining: 1.88s
# 256:	learn: 0.3923138	total: 646ms	remaining: 1.87s
# 257:	learn: 0.3922217	total: 649ms	remaining: 1.87s
# 258:	learn: 0.3921236	total: 651ms	remaining: 1.86s
# 259:	learn: 0.3920357	total: 653ms	remaining: 1.86s
# 260:	learn: 0.3919885	total: 656ms	remaining: 1.86s
# 261:	learn: 0.3918984	total: 658ms	remaining: 1.86s
# 262:	learn: 0.3918270	total: 661ms	remaining: 1.85s
# 263:	learn: 0.3917131	total: 663ms	remaining: 1.85s
# 264:	learn: 0.3916112	total: 666ms	remaining: 1.85s
# 265:	learn: 0.3915406	total: 668ms	remaining: 1.85s
# 266:	learn: 0.3913759	total: 672ms	remaining: 1.85s
# 267:	learn: 0.3912967	total: 674ms	remaining: 1.84s
# 268:	learn: 0.3912534	total: 677ms	remaining: 1.84s
# 269:	learn: 0.3911913	total: 679ms	remaining: 1.84s
# 270:	learn: 0.3911006	total: 682ms	remaining: 1.84s
# 271:	learn: 0.3910018	total: 684ms	remaining: 1.83s
# 272:	learn: 0.3909271	total: 688ms	remaining: 1.83s
# 273:	learn: 0.3908471	total: 690ms	remaining: 1.83s
# 274:	learn: 0.3907273	total: 692ms	remaining: 1.83s
# 275:	learn: 0.3906468	total: 694ms	remaining: 1.82s
# 276:	learn: 0.3905806	total: 697ms	remaining: 1.82s
# 277:	learn: 0.3904393	total: 699ms	remaining: 1.82s
# 278:	learn: 0.3903307	total: 701ms	remaining: 1.81s
# 279:	learn: 0.3902524	total: 704ms	remaining: 1.81s
# 280:	learn: 0.3901335	total: 706ms	remaining: 1.81s
# 281:	learn: 0.3900264	total: 708ms	remaining: 1.8s
# 282:	learn: 0.3899527	total: 711ms	remaining: 1.8s
# 283:	learn: 0.3898652	total: 713ms	remaining: 1.8s
# 284:	learn: 0.3898253	total: 715ms	remaining: 1.8s
# 285:	learn: 0.3897236	total: 718ms	remaining: 1.79s
# 286:	learn: 0.3896612	total: 720ms	remaining: 1.79s
# 287:	learn: 0.3896197	total: 722ms	remaining: 1.79s
# 288:	learn: 0.3895378	total: 725ms	remaining: 1.78s
# 289:	learn: 0.3894221	total: 727ms	remaining: 1.78s
# 290:	learn: 0.3893345	total: 729ms	remaining: 1.78s
# 291:	learn: 0.3892321	total: 732ms	remaining: 1.78s
# 292:	learn: 0.3891511	total: 734ms	remaining: 1.77s
# 293:	learn: 0.3890892	total: 737ms	remaining: 1.77s
# 294:	learn: 0.3890219	total: 739ms	remaining: 1.77s
# 295:	learn: 0.3889207	total: 741ms	remaining: 1.76s
# 296:	learn: 0.3888629	total: 744ms	remaining: 1.76s
# 297:	learn: 0.3888138	total: 746ms	remaining: 1.76s
# 298:	learn: 0.3887786	total: 748ms	remaining: 1.76s
# 299:	learn: 0.3886879	total: 750ms	remaining: 1.75s
# 300:	learn: 0.3886467	total: 752ms	remaining: 1.75s
# 301:	learn: 0.3885747	total: 755ms	remaining: 1.75s
# 302:	learn: 0.3885372	total: 757ms	remaining: 1.74s
# 303:	learn: 0.3884530	total: 759ms	remaining: 1.74s
# 304:	learn: 0.3883323	total: 762ms	remaining: 1.74s
# 305:	learn: 0.3882473	total: 764ms	remaining: 1.74s
# 306:	learn: 0.3880900	total: 767ms	remaining: 1.73s
# 307:	learn: 0.3880296	total: 769ms	remaining: 1.73s
# 308:	learn: 0.3879416	total: 771ms	remaining: 1.73s
# 309:	learn: 0.3878808	total: 774ms	remaining: 1.72s
# 310:	learn: 0.3877815	total: 776ms	remaining: 1.72s
# 311:	learn: 0.3876801	total: 778ms	remaining: 1.72s
# 312:	learn: 0.3875574	total: 781ms	remaining: 1.72s
# 313:	learn: 0.3874839	total: 784ms	remaining: 1.71s
# 314:	learn: 0.3874069	total: 786ms	remaining: 1.71s
# 315:	learn: 0.3873539	total: 788ms	remaining: 1.71s
# 316:	learn: 0.3872486	total: 791ms	remaining: 1.71s
# 317:	learn: 0.3871696	total: 794ms	remaining: 1.7s
# 318:	learn: 0.3870744	total: 796ms	remaining: 1.7s
# 319:	learn: 0.3869751	total: 799ms	remaining: 1.7s
# 320:	learn: 0.3868610	total: 801ms	remaining: 1.7s
# 321:	learn: 0.3867974	total: 803ms	remaining: 1.69s
# 322:	learn: 0.3866695	total: 805ms	remaining: 1.69s
# 323:	learn: 0.3866139	total: 808ms	remaining: 1.69s
# 324:	learn: 0.3865485	total: 810ms	remaining: 1.68s
# 325:	learn: 0.3864768	total: 812ms	remaining: 1.68s
# 326:	learn: 0.3863877	total: 815ms	remaining: 1.68s
# 327:	learn: 0.3863262	total: 817ms	remaining: 1.68s
# 328:	learn: 0.3862459	total: 820ms	remaining: 1.67s
# 329:	learn: 0.3861569	total: 822ms	remaining: 1.67s
# 330:	learn: 0.3860301	total: 824ms	remaining: 1.67s
# 331:	learn: 0.3859493	total: 826ms	remaining: 1.67s
# 332:	learn: 0.3858582	total: 829ms	remaining: 1.66s
# 333:	learn: 0.3857939	total: 831ms	remaining: 1.66s
# 334:	learn: 0.3856772	total: 834ms	remaining: 1.66s
# 335:	learn: 0.3855961	total: 836ms	remaining: 1.65s
# 336:	learn: 0.3855215	total: 838ms	remaining: 1.65s
# 337:	learn: 0.3854779	total: 841ms	remaining: 1.65s
# 338:	learn: 0.3854051	total: 843ms	remaining: 1.65s
# 339:	learn: 0.3853793	total: 845ms	remaining: 1.64s
# 340:	learn: 0.3853022	total: 847ms	remaining: 1.64s
# 341:	learn: 0.3852707	total: 849ms	remaining: 1.64s
# 342:	learn: 0.3851732	total: 852ms	remaining: 1.63s
# 343:	learn: 0.3850597	total: 854ms	remaining: 1.63s
# 344:	learn: 0.3849853	total: 856ms	remaining: 1.63s
# 345:	learn: 0.3849386	total: 859ms	remaining: 1.63s
# 346:	learn: 0.3848675	total: 861ms	remaining: 1.62s
# 347:	learn: 0.3847694	total: 863ms	remaining: 1.62s
# 348:	learn: 0.3846593	total: 866ms	remaining: 1.62s
# 349:	learn: 0.3844991	total: 868ms	remaining: 1.61s
# 350:	learn: 0.3843869	total: 870ms	remaining: 1.61s
# 351:	learn: 0.3842815	total: 873ms	remaining: 1.61s
# 352:	learn: 0.3842268	total: 875ms	remaining: 1.61s
# 353:	learn: 0.3841724	total: 878ms	remaining: 1.6s
# 354:	learn: 0.3841291	total: 880ms	remaining: 1.6s
# 355:	learn: 0.3840722	total: 882ms	remaining: 1.6s
# 356:	learn: 0.3840249	total: 884ms	remaining: 1.59s
# 357:	learn: 0.3839761	total: 887ms	remaining: 1.59s
# 358:	learn: 0.3839235	total: 889ms	remaining: 1.59s
# 359:	learn: 0.3838481	total: 891ms	remaining: 1.59s
# 360:	learn: 0.3837915	total: 894ms	remaining: 1.58s
# 361:	learn: 0.3837067	total: 896ms	remaining: 1.58s
# 362:	learn: 0.3836229	total: 898ms	remaining: 1.58s
# 363:	learn: 0.3835176	total: 901ms	remaining: 1.58s
# 364:	learn: 0.3833698	total: 904ms	remaining: 1.57s
# 365:	learn: 0.3832880	total: 906ms	remaining: 1.57s
# 366:	learn: 0.3831725	total: 909ms	remaining: 1.57s
# 367:	learn: 0.3830655	total: 911ms	remaining: 1.57s
# 368:	learn: 0.3829947	total: 913ms	remaining: 1.56s
# 369:	learn: 0.3829108	total: 916ms	remaining: 1.56s
# 370:	learn: 0.3828426	total: 918ms	remaining: 1.56s
# 371:	learn: 0.3827998	total: 921ms	remaining: 1.56s
# 372:	learn: 0.3827200	total: 923ms	remaining: 1.55s
# 373:	learn: 0.3826727	total: 925ms	remaining: 1.55s
# 374:	learn: 0.3826247	total: 928ms	remaining: 1.55s
# 375:	learn: 0.3825790	total: 930ms	remaining: 1.54s
# 376:	learn: 0.3824670	total: 932ms	remaining: 1.54s
# 377:	learn: 0.3823480	total: 934ms	remaining: 1.54s
# 378:	learn: 0.3822689	total: 937ms	remaining: 1.54s
# 379:	learn: 0.3821594	total: 939ms	remaining: 1.53s
# 380:	learn: 0.3820361	total: 941ms	remaining: 1.53s
# 381:	learn: 0.3819161	total: 943ms	remaining: 1.53s
# 382:	learn: 0.3818288	total: 945ms	remaining: 1.52s
# 383:	learn: 0.3817287	total: 947ms	remaining: 1.52s
# 384:	learn: 0.3816636	total: 950ms	remaining: 1.52s
# 385:	learn: 0.3816207	total: 952ms	remaining: 1.52s
# 386:	learn: 0.3814828	total: 955ms	remaining: 1.51s
# 387:	learn: 0.3813958	total: 957ms	remaining: 1.51s
# 388:	learn: 0.3813408	total: 959ms	remaining: 1.51s
# 389:	learn: 0.3812958	total: 961ms	remaining: 1.51s
# 390:	learn: 0.3812050	total: 964ms	remaining: 1.5s
# 391:	learn: 0.3811483	total: 966ms	remaining: 1.5s
# 392:	learn: 0.3810698	total: 968ms	remaining: 1.5s
# 393:	learn: 0.3809681	total: 971ms	remaining: 1.5s
# 394:	learn: 0.3808615	total: 973ms	remaining: 1.49s
# 395:	learn: 0.3808237	total: 976ms	remaining: 1.49s
# 396:	learn: 0.3806991	total: 978ms	remaining: 1.49s
# 397:	learn: 0.3806271	total: 981ms	remaining: 1.49s
# 398:	learn: 0.3805415	total: 983ms	remaining: 1.48s
# 399:	learn: 0.3805020	total: 985ms	remaining: 1.48s
# 400:	learn: 0.3804484	total: 988ms	remaining: 1.48s
# 401:	learn: 0.3803603	total: 990ms	remaining: 1.48s
# 402:	learn: 0.3803096	total: 992ms	remaining: 1.47s
# 403:	learn: 0.3802460	total: 995ms	remaining: 1.47s
# 404:	learn: 0.3801843	total: 997ms	remaining: 1.47s
# 405:	learn: 0.3801356	total: 999ms	remaining: 1.46s
# 406:	learn: 0.3800402	total: 1s	remaining: 1.46s
# 407:	learn: 0.3799818	total: 1s	remaining: 1.46s
# 408:	learn: 0.3799108	total: 1.01s	remaining: 1.46s
# 409:	learn: 0.3798135	total: 1.01s	remaining: 1.45s
# 410:	learn: 0.3797049	total: 1.01s	remaining: 1.45s
# 411:	learn: 0.3795963	total: 1.01s	remaining: 1.45s
# 412:	learn: 0.3794896	total: 1.01s	remaining: 1.45s
# 413:	learn: 0.3793870	total: 1.02s	remaining: 1.44s
# 414:	learn: 0.3792864	total: 1.02s	remaining: 1.44s
# 415:	learn: 0.3792050	total: 1.02s	remaining: 1.44s
# 416:	learn: 0.3791616	total: 1.02s	remaining: 1.44s
# 417:	learn: 0.3790704	total: 1.03s	remaining: 1.43s
# 418:	learn: 0.3790167	total: 1.03s	remaining: 1.43s
# 419:	learn: 0.3789614	total: 1.03s	remaining: 1.43s
# 420:	learn: 0.3788987	total: 1.03s	remaining: 1.43s
# 421:	learn: 0.3788362	total: 1.04s	remaining: 1.42s
# 422:	learn: 0.3787537	total: 1.04s	remaining: 1.42s
# 423:	learn: 0.3786592	total: 1.04s	remaining: 1.42s
# 424:	learn: 0.3785980	total: 1.04s	remaining: 1.42s
# 425:	learn: 0.3785504	total: 1.05s	remaining: 1.42s
# 426:	learn: 0.3784814	total: 1.06s	remaining: 1.42s
# 427:	learn: 0.3783842	total: 1.06s	remaining: 1.42s
# 428:	learn: 0.3783167	total: 1.07s	remaining: 1.42s
# 429:	learn: 0.3782299	total: 1.07s	remaining: 1.42s
# 430:	learn: 0.3781727	total: 1.07s	remaining: 1.42s
# 431:	learn: 0.3780902	total: 1.07s	remaining: 1.41s
# 432:	learn: 0.3779944	total: 1.08s	remaining: 1.41s
# 433:	learn: 0.3778691	total: 1.08s	remaining: 1.41s
# 434:	learn: 0.3777830	total: 1.08s	remaining: 1.41s
# 435:	learn: 0.3777247	total: 1.08s	remaining: 1.4s
# 436:	learn: 0.3776417	total: 1.09s	remaining: 1.4s
# 437:	learn: 0.3775613	total: 1.09s	remaining: 1.4s
# 438:	learn: 0.3775083	total: 1.09s	remaining: 1.4s
# 439:	learn: 0.3774026	total: 1.09s	remaining: 1.39s
# 440:	learn: 0.3773504	total: 1.09s	remaining: 1.39s
# 441:	learn: 0.3772926	total: 1.1s	remaining: 1.39s
# 442:	learn: 0.3772392	total: 1.1s	remaining: 1.39s
# 443:	learn: 0.3771882	total: 1.1s	remaining: 1.38s
# 444:	learn: 0.3771260	total: 1.1s	remaining: 1.38s
# 445:	learn: 0.3770577	total: 1.11s	remaining: 1.38s
# 446:	learn: 0.3769657	total: 1.11s	remaining: 1.38s
# 447:	learn: 0.3769019	total: 1.11s	remaining: 1.37s
# 448:	learn: 0.3768479	total: 1.11s	remaining: 1.37s
# 449:	learn: 0.3767452	total: 1.12s	remaining: 1.37s
# 450:	learn: 0.3766552	total: 1.12s	remaining: 1.36s
# 451:	learn: 0.3765812	total: 1.12s	remaining: 1.36s
# 452:	learn: 0.3765174	total: 1.12s	remaining: 1.36s
# 453:	learn: 0.3764661	total: 1.13s	remaining: 1.36s
# 454:	learn: 0.3764168	total: 1.13s	remaining: 1.35s
# 455:	learn: 0.3763139	total: 1.13s	remaining: 1.35s
# 456:	learn: 0.3762772	total: 1.13s	remaining: 1.35s
# 457:	learn: 0.3762110	total: 1.14s	remaining: 1.35s
# 458:	learn: 0.3761226	total: 1.14s	remaining: 1.34s
# 459:	learn: 0.3760120	total: 1.14s	remaining: 1.34s
# 460:	learn: 0.3758952	total: 1.14s	remaining: 1.34s
# 461:	learn: 0.3758117	total: 1.15s	remaining: 1.34s
# 462:	learn: 0.3757587	total: 1.15s	remaining: 1.33s
# 463:	learn: 0.3756779	total: 1.15s	remaining: 1.33s
# 464:	learn: 0.3756066	total: 1.15s	remaining: 1.33s
# 465:	learn: 0.3755304	total: 1.15s	remaining: 1.32s
# 466:	learn: 0.3754667	total: 1.16s	remaining: 1.32s
# 467:	learn: 0.3753833	total: 1.16s	remaining: 1.32s
# 468:	learn: 0.3753076	total: 1.16s	remaining: 1.32s
# 469:	learn: 0.3752461	total: 1.16s	remaining: 1.31s
# 470:	learn: 0.3751815	total: 1.17s	remaining: 1.31s
# 471:	learn: 0.3750880	total: 1.17s	remaining: 1.31s
# 472:	learn: 0.3750399	total: 1.17s	remaining: 1.31s
# 473:	learn: 0.3749945	total: 1.17s	remaining: 1.3s
# 474:	learn: 0.3749421	total: 1.18s	remaining: 1.3s
# 475:	learn: 0.3748760	total: 1.18s	remaining: 1.3s
# 476:	learn: 0.3748043	total: 1.18s	remaining: 1.3s
# 477:	learn: 0.3747383	total: 1.18s	remaining: 1.29s
# 478:	learn: 0.3746564	total: 1.19s	remaining: 1.29s
# 479:	learn: 0.3745973	total: 1.19s	remaining: 1.29s
# 480:	learn: 0.3745315	total: 1.19s	remaining: 1.29s
# 481:	learn: 0.3744438	total: 1.19s	remaining: 1.28s
# 482:	learn: 0.3743929	total: 1.19s	remaining: 1.28s
# 483:	learn: 0.3743300	total: 1.2s	remaining: 1.28s
# 484:	learn: 0.3742249	total: 1.2s	remaining: 1.27s
# 485:	learn: 0.3741329	total: 1.2s	remaining: 1.27s
# 486:	learn: 0.3740856	total: 1.2s	remaining: 1.27s
# 487:	learn: 0.3739807	total: 1.21s	remaining: 1.27s
# 488:	learn: 0.3739229	total: 1.21s	remaining: 1.26s
# 489:	learn: 0.3738651	total: 1.21s	remaining: 1.26s
# 490:	learn: 0.3737782	total: 1.21s	remaining: 1.26s
# 491:	learn: 0.3736915	total: 1.22s	remaining: 1.26s
# 492:	learn: 0.3736115	total: 1.22s	remaining: 1.25s
# 493:	learn: 0.3735605	total: 1.22s	remaining: 1.25s
# 494:	learn: 0.3734980	total: 1.22s	remaining: 1.25s
# 495:	learn: 0.3734498	total: 1.22s	remaining: 1.25s
# 496:	learn: 0.3733605	total: 1.23s	remaining: 1.24s
# 497:	learn: 0.3733077	total: 1.23s	remaining: 1.24s
# 498:	learn: 0.3732308	total: 1.23s	remaining: 1.24s
# 499:	learn: 0.3731570	total: 1.23s	remaining: 1.24s
# 500:	learn: 0.3731014	total: 1.24s	remaining: 1.23s
# 501:	learn: 0.3730446	total: 1.24s	remaining: 1.23s
# 502:	learn: 0.3729766	total: 1.24s	remaining: 1.23s
# 503:	learn: 0.3728958	total: 1.24s	remaining: 1.22s
# 504:	learn: 0.3728194	total: 1.24s	remaining: 1.22s
# 505:	learn: 0.3727603	total: 1.25s	remaining: 1.22s
# 506:	learn: 0.3727067	total: 1.25s	remaining: 1.22s
# 507:	learn: 0.3726616	total: 1.25s	remaining: 1.21s
# 508:	learn: 0.3725936	total: 1.25s	remaining: 1.21s
# 509:	learn: 0.3725266	total: 1.26s	remaining: 1.21s
# 510:	learn: 0.3724715	total: 1.26s	remaining: 1.21s
# 511:	learn: 0.3724056	total: 1.26s	remaining: 1.2s
# 512:	learn: 0.3723147	total: 1.26s	remaining: 1.2s
# 513:	learn: 0.3722594	total: 1.26s	remaining: 1.2s
# 514:	learn: 0.3721634	total: 1.27s	remaining: 1.2s
# 515:	learn: 0.3721258	total: 1.27s	remaining: 1.19s
# 516:	learn: 0.3720606	total: 1.27s	remaining: 1.19s
# 517:	learn: 0.3719264	total: 1.27s	remaining: 1.19s
# 518:	learn: 0.3718694	total: 1.28s	remaining: 1.19s
# 519:	learn: 0.3717983	total: 1.28s	remaining: 1.18s
# 520:	learn: 0.3717233	total: 1.28s	remaining: 1.18s
# 521:	learn: 0.3716502	total: 1.28s	remaining: 1.18s
# 522:	learn: 0.3716013	total: 1.29s	remaining: 1.18s
# 523:	learn: 0.3715648	total: 1.29s	remaining: 1.17s
# 524:	learn: 0.3714734	total: 1.29s	remaining: 1.17s
# 525:	learn: 0.3714034	total: 1.29s	remaining: 1.17s
# 526:	learn: 0.3713129	total: 1.29s	remaining: 1.17s
# 527:	learn: 0.3712160	total: 1.3s	remaining: 1.16s
# 528:	learn: 0.3710863	total: 1.3s	remaining: 1.16s
# 529:	learn: 0.3710141	total: 1.3s	remaining: 1.16s
# 530:	learn: 0.3708871	total: 1.3s	remaining: 1.16s
# 531:	learn: 0.3707807	total: 1.31s	remaining: 1.15s
# 532:	learn: 0.3707173	total: 1.31s	remaining: 1.15s
# 533:	learn: 0.3706371	total: 1.31s	remaining: 1.15s
# 534:	learn: 0.3705401	total: 1.31s	remaining: 1.14s
# 535:	learn: 0.3704539	total: 1.32s	remaining: 1.14s
# 536:	learn: 0.3703540	total: 1.32s	remaining: 1.14s
# 537:	learn: 0.3702897	total: 1.32s	remaining: 1.14s
# 538:	learn: 0.3702360	total: 1.32s	remaining: 1.13s
# 539:	learn: 0.3701624	total: 1.32s	remaining: 1.13s
# 540:	learn: 0.3700998	total: 1.33s	remaining: 1.13s
# 541:	learn: 0.3699718	total: 1.33s	remaining: 1.13s
# 542:	learn: 0.3698771	total: 1.33s	remaining: 1.12s
# 543:	learn: 0.3698520	total: 1.33s	remaining: 1.12s
# 544:	learn: 0.3698070	total: 1.34s	remaining: 1.12s
# 545:	learn: 0.3697252	total: 1.34s	remaining: 1.11s
# 546:	learn: 0.3696618	total: 1.34s	remaining: 1.11s
# 547:	learn: 0.3695937	total: 1.34s	remaining: 1.11s
# 548:	learn: 0.3695254	total: 1.34s	remaining: 1.11s
# 549:	learn: 0.3694767	total: 1.35s	remaining: 1.1s
# 550:	learn: 0.3694320	total: 1.35s	remaining: 1.1s
# 551:	learn: 0.3693385	total: 1.35s	remaining: 1.1s
# 552:	learn: 0.3692882	total: 1.35s	remaining: 1.1s
# 553:	learn: 0.3692015	total: 1.36s	remaining: 1.09s
# 554:	learn: 0.3691676	total: 1.36s	remaining: 1.09s
# 555:	learn: 0.3690733	total: 1.36s	remaining: 1.09s
# 556:	learn: 0.3689973	total: 1.36s	remaining: 1.09s
# 557:	learn: 0.3689499	total: 1.37s	remaining: 1.08s
# 558:	learn: 0.3688992	total: 1.37s	remaining: 1.08s
# 559:	learn: 0.3688433	total: 1.37s	remaining: 1.08s
# 560:	learn: 0.3687500	total: 1.37s	remaining: 1.08s
# 561:	learn: 0.3686747	total: 1.38s	remaining: 1.07s
# 562:	learn: 0.3685643	total: 1.38s	remaining: 1.07s
# 563:	learn: 0.3685178	total: 1.38s	remaining: 1.07s
# 564:	learn: 0.3684374	total: 1.38s	remaining: 1.07s
# 565:	learn: 0.3683647	total: 1.39s	remaining: 1.06s
# 566:	learn: 0.3683160	total: 1.39s	remaining: 1.06s
# 567:	learn: 0.3682321	total: 1.39s	remaining: 1.06s
# 568:	learn: 0.3681427	total: 1.39s	remaining: 1.06s
# 569:	learn: 0.3680611	total: 1.4s	remaining: 1.05s
# 570:	learn: 0.3679650	total: 1.4s	remaining: 1.05s
# 571:	learn: 0.3678793	total: 1.4s	remaining: 1.05s
# 572:	learn: 0.3678374	total: 1.4s	remaining: 1.05s
# 573:	learn: 0.3677560	total: 1.4s	remaining: 1.04s
# 574:	learn: 0.3676664	total: 1.41s	remaining: 1.04s
# 575:	learn: 0.3675831	total: 1.41s	remaining: 1.04s
# 576:	learn: 0.3675254	total: 1.41s	remaining: 1.04s
# 577:	learn: 0.3674032	total: 1.41s	remaining: 1.03s
# 578:	learn: 0.3673481	total: 1.42s	remaining: 1.03s
# 579:	learn: 0.3673004	total: 1.42s	remaining: 1.03s
# 580:	learn: 0.3672136	total: 1.42s	remaining: 1.03s
# 581:	learn: 0.3671532	total: 1.43s	remaining: 1.03s
# 582:	learn: 0.3670779	total: 1.43s	remaining: 1.03s
# 583:	learn: 0.3669581	total: 1.44s	remaining: 1.02s
# 584:	learn: 0.3669088	total: 1.44s	remaining: 1.02s
# 585:	learn: 0.3668591	total: 1.44s	remaining: 1.02s
# 586:	learn: 0.3668331	total: 1.44s	remaining: 1.02s
# 587:	learn: 0.3667853	total: 1.45s	remaining: 1.01s
# 588:	learn: 0.3666847	total: 1.45s	remaining: 1.01s
# 589:	learn: 0.3665975	total: 1.45s	remaining: 1.01s
# 590:	learn: 0.3665107	total: 1.45s	remaining: 1.01s
# 591:	learn: 0.3664175	total: 1.46s	remaining: 1s
# 592:	learn: 0.3663567	total: 1.46s	remaining: 1s
# 593:	learn: 0.3662796	total: 1.46s	remaining: 1s
# 594:	learn: 0.3661881	total: 1.46s	remaining: 998ms
# 595:	learn: 0.3661041	total: 1.47s	remaining: 996ms
# 596:	learn: 0.3660218	total: 1.47s	remaining: 993ms
# 597:	learn: 0.3659884	total: 1.47s	remaining: 991ms
# 598:	learn: 0.3659217	total: 1.47s	remaining: 988ms
# 599:	learn: 0.3658698	total: 1.47s	remaining: 985ms
# 600:	learn: 0.3657967	total: 1.48s	remaining: 983ms
# 601:	learn: 0.3657305	total: 1.48s	remaining: 980ms
# 602:	learn: 0.3656287	total: 1.48s	remaining: 978ms
# 603:	learn: 0.3655821	total: 1.48s	remaining: 975ms
# 604:	learn: 0.3654922	total: 1.49s	remaining: 973ms
# 605:	learn: 0.3654069	total: 1.49s	remaining: 971ms
# 606:	learn: 0.3653405	total: 1.49s	remaining: 968ms
# 607:	learn: 0.3652662	total: 1.49s	remaining: 965ms
# 608:	learn: 0.3652164	total: 1.5s	remaining: 963ms
# 609:	learn: 0.3651708	total: 1.5s	remaining: 961ms
# 610:	learn: 0.3651351	total: 1.5s	remaining: 958ms
# 611:	learn: 0.3650315	total: 1.5s	remaining: 955ms
# 612:	learn: 0.3650019	total: 1.51s	remaining: 953ms
# 613:	learn: 0.3649649	total: 1.51s	remaining: 951ms
# 614:	learn: 0.3648877	total: 1.51s	remaining: 949ms
# 615:	learn: 0.3648018	total: 1.51s	remaining: 946ms
# 616:	learn: 0.3647426	total: 1.51s	remaining: 943ms
# 617:	learn: 0.3646837	total: 1.52s	remaining: 941ms
# 618:	learn: 0.3646066	total: 1.52s	remaining: 938ms
# 619:	learn: 0.3645604	total: 1.52s	remaining: 936ms
# 620:	learn: 0.3645244	total: 1.52s	remaining: 933ms
# 621:	learn: 0.3644616	total: 1.53s	remaining: 931ms
# 622:	learn: 0.3643318	total: 1.53s	remaining: 928ms
# 623:	learn: 0.3642198	total: 1.53s	remaining: 926ms
# 624:	learn: 0.3641400	total: 1.53s	remaining: 923ms
# 625:	learn: 0.3640156	total: 1.54s	remaining: 921ms
# 626:	learn: 0.3639857	total: 1.54s	remaining: 918ms
# 627:	learn: 0.3638804	total: 1.54s	remaining: 916ms
# 628:	learn: 0.3638465	total: 1.54s	remaining: 913ms
# 629:	learn: 0.3637680	total: 1.54s	remaining: 910ms
# 630:	learn: 0.3636536	total: 1.55s	remaining: 908ms
# 631:	learn: 0.3635517	total: 1.55s	remaining: 905ms
# 632:	learn: 0.3635174	total: 1.55s	remaining: 903ms
# 633:	learn: 0.3634502	total: 1.55s	remaining: 900ms
# 634:	learn: 0.3634100	total: 1.56s	remaining: 897ms
# 635:	learn: 0.3633323	total: 1.56s	remaining: 895ms
# 636:	learn: 0.3632775	total: 1.56s	remaining: 893ms
# 637:	learn: 0.3632028	total: 1.56s	remaining: 890ms
# 638:	learn: 0.3630887	total: 1.57s	remaining: 887ms
# 639:	learn: 0.3630267	total: 1.57s	remaining: 885ms
# 640:	learn: 0.3629445	total: 1.57s	remaining: 883ms
# 641:	learn: 0.3628371	total: 1.57s	remaining: 880ms
# 642:	learn: 0.3627759	total: 1.57s	remaining: 877ms
# 643:	learn: 0.3627278	total: 1.58s	remaining: 875ms
# 644:	learn: 0.3626912	total: 1.58s	remaining: 873ms
# 645:	learn: 0.3625859	total: 1.58s	remaining: 871ms
# 646:	learn: 0.3624650	total: 1.59s	remaining: 868ms
# 647:	learn: 0.3624211	total: 1.59s	remaining: 866ms
# 648:	learn: 0.3623602	total: 1.59s	remaining: 863ms
# 649:	learn: 0.3623112	total: 1.59s	remaining: 860ms
# 650:	learn: 0.3622265	total: 1.59s	remaining: 858ms
# 651:	learn: 0.3621439	total: 1.6s	remaining: 855ms
# 652:	learn: 0.3620716	total: 1.6s	remaining: 853ms
# 653:	learn: 0.3620292	total: 1.6s	remaining: 850ms
# 654:	learn: 0.3619561	total: 1.6s	remaining: 848ms
# 655:	learn: 0.3618349	total: 1.61s	remaining: 846ms
# 656:	learn: 0.3617535	total: 1.61s	remaining: 844ms
# 657:	learn: 0.3617226	total: 1.61s	remaining: 841ms
# 658:	learn: 0.3616838	total: 1.61s	remaining: 839ms
# 659:	learn: 0.3616379	total: 1.62s	remaining: 836ms
# 660:	learn: 0.3615909	total: 1.62s	remaining: 834ms
# 661:	learn: 0.3615130	total: 1.62s	remaining: 831ms
# 662:	learn: 0.3614893	total: 1.63s	remaining: 829ms
# 663:	learn: 0.3614405	total: 1.63s	remaining: 826ms
# 664:	learn: 0.3613895	total: 1.63s	remaining: 823ms
# 665:	learn: 0.3613187	total: 1.63s	remaining: 821ms
# 666:	learn: 0.3612541	total: 1.64s	remaining: 819ms
# 667:	learn: 0.3612132	total: 1.64s	remaining: 816ms
# 668:	learn: 0.3611647	total: 1.64s	remaining: 814ms
# 669:	learn: 0.3610713	total: 1.64s	remaining: 811ms
# 670:	learn: 0.3610119	total: 1.64s	remaining: 809ms
# 671:	learn: 0.3609343	total: 1.65s	remaining: 806ms
# 672:	learn: 0.3608985	total: 1.65s	remaining: 804ms
# 673:	learn: 0.3607948	total: 1.65s	remaining: 801ms
# 674:	learn: 0.3607231	total: 1.65s	remaining: 799ms
# 675:	learn: 0.3606663	total: 1.66s	remaining: 796ms
# 676:	learn: 0.3606243	total: 1.66s	remaining: 794ms
# 677:	learn: 0.3605955	total: 1.66s	remaining: 791ms
# 678:	learn: 0.3604888	total: 1.66s	remaining: 789ms
# 679:	learn: 0.3604603	total: 1.67s	remaining: 786ms
# 680:	learn: 0.3603622	total: 1.67s	remaining: 784ms
# 681:	learn: 0.3603084	total: 1.67s	remaining: 781ms
# 682:	learn: 0.3602721	total: 1.67s	remaining: 779ms
# 683:	learn: 0.3602079	total: 1.67s	remaining: 776ms
# 684:	learn: 0.3601874	total: 1.68s	remaining: 774ms
# 685:	learn: 0.3601410	total: 1.68s	remaining: 771ms
# 686:	learn: 0.3601031	total: 1.68s	remaining: 769ms
# 687:	learn: 0.3600668	total: 1.68s	remaining: 766ms
# 688:	learn: 0.3600172	total: 1.69s	remaining: 764ms
# 689:	learn: 0.3599519	total: 1.69s	remaining: 761ms
# 690:	learn: 0.3599206	total: 1.69s	remaining: 759ms
# 691:	learn: 0.3598849	total: 1.69s	remaining: 756ms
# 692:	learn: 0.3598417	total: 1.7s	remaining: 754ms
# 693:	learn: 0.3598044	total: 1.7s	remaining: 751ms
# 694:	learn: 0.3597359	total: 1.7s	remaining: 748ms
# 695:	learn: 0.3596925	total: 1.7s	remaining: 746ms
# 696:	learn: 0.3595881	total: 1.71s	remaining: 744ms
# 697:	learn: 0.3595259	total: 1.71s	remaining: 741ms
# 698:	learn: 0.3594848	total: 1.71s	remaining: 738ms
# 699:	learn: 0.3594347	total: 1.71s	remaining: 736ms
# 700:	learn: 0.3593893	total: 1.71s	remaining: 733ms
# 701:	learn: 0.3593485	total: 1.72s	remaining: 731ms
# 702:	learn: 0.3592860	total: 1.72s	remaining: 728ms
# 703:	learn: 0.3592325	total: 1.72s	remaining: 726ms
# 704:	learn: 0.3591976	total: 1.72s	remaining: 723ms
# 705:	learn: 0.3591393	total: 1.72s	remaining: 720ms
# 706:	learn: 0.3591006	total: 1.73s	remaining: 718ms
# 707:	learn: 0.3590255	total: 1.73s	remaining: 715ms
# 708:	learn: 0.3589910	total: 1.73s	remaining: 713ms
# 709:	learn: 0.3588783	total: 1.73s	remaining: 710ms
# 710:	learn: 0.3588437	total: 1.74s	remaining: 708ms
# 711:	learn: 0.3587569	total: 1.74s	remaining: 705ms
# 712:	learn: 0.3586883	total: 1.74s	remaining: 703ms
# 713:	learn: 0.3586471	total: 1.74s	remaining: 701ms
# 714:	learn: 0.3586070	total: 1.75s	remaining: 698ms
# 715:	learn: 0.3585307	total: 1.75s	remaining: 696ms
# 716:	learn: 0.3584190	total: 1.75s	remaining: 693ms
# 717:	learn: 0.3583807	total: 1.75s	remaining: 691ms
# 718:	learn: 0.3582827	total: 1.75s	remaining: 689ms
# 719:	learn: 0.3582002	total: 1.76s	remaining: 686ms
# 720:	learn: 0.3581324	total: 1.76s	remaining: 684ms
# 721:	learn: 0.3580897	total: 1.76s	remaining: 681ms
# 722:	learn: 0.3580265	total: 1.76s	remaining: 679ms
# 723:	learn: 0.3579276	total: 1.77s	remaining: 676ms
# 724:	learn: 0.3578936	total: 1.77s	remaining: 674ms
# 725:	learn: 0.3578099	total: 1.77s	remaining: 671ms
# 726:	learn: 0.3577001	total: 1.77s	remaining: 669ms
# 727:	learn: 0.3576426	total: 1.78s	remaining: 666ms
# 728:	learn: 0.3575487	total: 1.78s	remaining: 664ms
# 729:	learn: 0.3575096	total: 1.78s	remaining: 661ms
# 730:	learn: 0.3574039	total: 1.78s	remaining: 659ms
# 731:	learn: 0.3573369	total: 1.79s	remaining: 657ms
# 732:	learn: 0.3572847	total: 1.79s	remaining: 654ms
# 733:	learn: 0.3572306	total: 1.79s	remaining: 652ms
# 734:	learn: 0.3571766	total: 1.79s	remaining: 649ms
# 735:	learn: 0.3571444	total: 1.8s	remaining: 647ms
# 736:	learn: 0.3570860	total: 1.8s	remaining: 644ms
# 737:	learn: 0.3570468	total: 1.8s	remaining: 642ms
# 738:	learn: 0.3570059	total: 1.8s	remaining: 639ms
# 739:	learn: 0.3569549	total: 1.8s	remaining: 637ms
# 740:	learn: 0.3568970	total: 1.81s	remaining: 634ms
# 741:	learn: 0.3567971	total: 1.81s	remaining: 632ms
# 742:	learn: 0.3567231	total: 1.81s	remaining: 629ms
# 743:	learn: 0.3566478	total: 1.81s	remaining: 627ms
# 744:	learn: 0.3565730	total: 1.82s	remaining: 624ms
# 745:	learn: 0.3565117	total: 1.82s	remaining: 622ms
# 746:	learn: 0.3564637	total: 1.82s	remaining: 619ms
# 747:	learn: 0.3564091	total: 1.82s	remaining: 617ms
# 748:	learn: 0.3563568	total: 1.83s	remaining: 615ms
# 749:	learn: 0.3562810	total: 1.83s	remaining: 612ms
# 750:	learn: 0.3562182	total: 1.83s	remaining: 610ms
# 751:	learn: 0.3561570	total: 1.83s	remaining: 608ms
# 752:	learn: 0.3560961	total: 1.84s	remaining: 605ms
# 753:	learn: 0.3560283	total: 1.84s	remaining: 603ms
# 754:	learn: 0.3559667	total: 1.84s	remaining: 600ms
# 755:	learn: 0.3559150	total: 1.84s	remaining: 598ms
# 756:	learn: 0.3558645	total: 1.85s	remaining: 595ms
# 757:	learn: 0.3558325	total: 1.85s	remaining: 593ms
# 758:	learn: 0.3557417	total: 1.85s	remaining: 591ms
# 759:	learn: 0.3556918	total: 1.85s	remaining: 588ms
# 760:	learn: 0.3556643	total: 1.86s	remaining: 586ms
# 761:	learn: 0.3556332	total: 1.86s	remaining: 583ms
# 762:	learn: 0.3555373	total: 1.86s	remaining: 581ms
# 763:	learn: 0.3554380	total: 1.86s	remaining: 578ms
# 764:	learn: 0.3553469	total: 1.87s	remaining: 576ms
# 765:	learn: 0.3552933	total: 1.87s	remaining: 573ms
# 766:	learn: 0.3552028	total: 1.87s	remaining: 571ms
# 767:	learn: 0.3551703	total: 1.87s	remaining: 568ms
# 768:	learn: 0.3551188	total: 1.88s	remaining: 566ms
# 769:	learn: 0.3550535	total: 1.88s	remaining: 563ms
# 770:	learn: 0.3549859	total: 1.88s	remaining: 561ms
# 771:	learn: 0.3549566	total: 1.88s	remaining: 558ms
# 772:	learn: 0.3549253	total: 1.88s	remaining: 556ms
# 773:	learn: 0.3548597	total: 1.89s	remaining: 553ms
# 774:	learn: 0.3548107	total: 1.89s	remaining: 551ms
# 775:	learn: 0.3547175	total: 1.89s	remaining: 549ms
# 776:	learn: 0.3546634	total: 1.89s	remaining: 546ms
# 777:	learn: 0.3546335	total: 1.9s	remaining: 543ms
# 778:	learn: 0.3545821	total: 1.9s	remaining: 541ms
# 779:	learn: 0.3545094	total: 1.9s	remaining: 538ms
# 780:	learn: 0.3543888	total: 1.9s	remaining: 536ms
# 781:	learn: 0.3542863	total: 1.91s	remaining: 534ms
# 782:	learn: 0.3542566	total: 1.91s	remaining: 531ms
# 783:	learn: 0.3541530	total: 1.91s	remaining: 529ms
# 784:	learn: 0.3541203	total: 1.91s	remaining: 526ms
# 785:	learn: 0.3540516	total: 1.91s	remaining: 524ms
# 786:	learn: 0.3539696	total: 1.92s	remaining: 521ms
# 787:	learn: 0.3539251	total: 1.92s	remaining: 519ms
# 788:	learn: 0.3538703	total: 1.92s	remaining: 516ms
# 789:	learn: 0.3538018	total: 1.92s	remaining: 514ms
# 790:	learn: 0.3537650	total: 1.93s	remaining: 511ms
# 791:	learn: 0.3536857	total: 1.93s	remaining: 509ms
# 792:	learn: 0.3536260	total: 1.93s	remaining: 506ms
# 793:	learn: 0.3535547	total: 1.93s	remaining: 504ms
# 794:	learn: 0.3534851	total: 1.94s	remaining: 502ms
# 795:	learn: 0.3534080	total: 1.94s	remaining: 499ms
# 796:	learn: 0.3533663	total: 1.94s	remaining: 497ms
# 797:	learn: 0.3533283	total: 1.94s	remaining: 494ms
# 798:	learn: 0.3532351	total: 1.94s	remaining: 492ms
# 799:	learn: 0.3531642	total: 1.95s	remaining: 489ms
# 800:	learn: 0.3531089	total: 1.95s	remaining: 487ms
# 801:	learn: 0.3530693	total: 1.95s	remaining: 485ms
# 802:	learn: 0.3530398	total: 1.96s	remaining: 482ms
# 803:	learn: 0.3530130	total: 1.96s	remaining: 480ms
# 804:	learn: 0.3529560	total: 1.96s	remaining: 477ms
# 805:	learn: 0.3528798	total: 1.96s	remaining: 475ms
# 806:	learn: 0.3527759	total: 1.97s	remaining: 472ms
# 807:	learn: 0.3527281	total: 1.97s	remaining: 470ms
# 808:	learn: 0.3526546	total: 1.97s	remaining: 467ms
# 809:	learn: 0.3526257	total: 1.97s	remaining: 465ms
# 810:	learn: 0.3525884	total: 1.97s	remaining: 463ms
# 811:	learn: 0.3525137	total: 1.98s	remaining: 460ms
# 812:	learn: 0.3524626	total: 1.98s	remaining: 458ms
# 813:	learn: 0.3524247	total: 1.98s	remaining: 455ms
# 814:	learn: 0.3523895	total: 1.98s	remaining: 453ms
# 815:	learn: 0.3523109	total: 1.99s	remaining: 450ms
# 816:	learn: 0.3522521	total: 1.99s	remaining: 448ms
# 817:	learn: 0.3521666	total: 1.99s	remaining: 446ms
# 818:	learn: 0.3520969	total: 1.99s	remaining: 443ms
# 819:	learn: 0.3520105	total: 2s	remaining: 441ms
# 820:	learn: 0.3519259	total: 2s	remaining: 438ms
# 821:	learn: 0.3518564	total: 2s	remaining: 436ms
# 822:	learn: 0.3518082	total: 2s	remaining: 433ms
# 823:	learn: 0.3517187	total: 2s	remaining: 431ms
# 824:	learn: 0.3516315	total: 2.01s	remaining: 428ms
# 825:	learn: 0.3515717	total: 2.01s	remaining: 426ms
# 826:	learn: 0.3515000	total: 2.01s	remaining: 423ms
# 827:	learn: 0.3514376	total: 2.01s	remaining: 421ms
# 828:	learn: 0.3513893	total: 2.02s	remaining: 419ms
# 829:	learn: 0.3513257	total: 2.02s	remaining: 416ms
# 830:	learn: 0.3512599	total: 2.02s	remaining: 414ms
# 831:	learn: 0.3511993	total: 2.02s	remaining: 411ms
# 832:	learn: 0.3511456	total: 2.03s	remaining: 409ms
# 833:	learn: 0.3510876	total: 2.03s	remaining: 406ms
# 834:	learn: 0.3509868	total: 2.03s	remaining: 404ms
# 835:	learn: 0.3509399	total: 2.03s	remaining: 401ms
# 836:	learn: 0.3508864	total: 2.04s	remaining: 400ms
# 837:	learn: 0.3508274	total: 2.04s	remaining: 397ms
# 838:	learn: 0.3507851	total: 2.05s	remaining: 396ms
# 839:	learn: 0.3507149	total: 2.05s	remaining: 394ms
# 840:	learn: 0.3506611	total: 2.06s	remaining: 391ms
# 841:	learn: 0.3506330	total: 2.06s	remaining: 389ms
# 842:	learn: 0.3505885	total: 2.06s	remaining: 387ms
# 843:	learn: 0.3505455	total: 2.06s	remaining: 384ms
# 844:	learn: 0.3504862	total: 2.07s	remaining: 382ms
# 845:	learn: 0.3504170	total: 2.07s	remaining: 379ms
# 846:	learn: 0.3503523	total: 2.07s	remaining: 377ms
# 847:	learn: 0.3502871	total: 2.08s	remaining: 374ms
# 848:	learn: 0.3502615	total: 2.08s	remaining: 372ms
# 849:	learn: 0.3501676	total: 2.08s	remaining: 369ms
# 850:	learn: 0.3500948	total: 2.08s	remaining: 367ms
# 851:	learn: 0.3500249	total: 2.08s	remaining: 365ms
# 852:	learn: 0.3499841	total: 2.09s	remaining: 362ms
# 853:	learn: 0.3499206	total: 2.09s	remaining: 360ms
# 854:	learn: 0.3498661	total: 2.09s	remaining: 357ms
# 855:	learn: 0.3498385	total: 2.09s	remaining: 355ms
# 856:	learn: 0.3497767	total: 2.1s	remaining: 352ms
# 857:	learn: 0.3497141	total: 2.1s	remaining: 350ms
# 858:	learn: 0.3496485	total: 2.1s	remaining: 347ms
# 859:	learn: 0.3495888	total: 2.1s	remaining: 345ms
# 860:	learn: 0.3495259	total: 2.1s	remaining: 342ms
# 861:	learn: 0.3494603	total: 2.11s	remaining: 340ms
# 862:	learn: 0.3493993	total: 2.11s	remaining: 337ms
# 863:	learn: 0.3493193	total: 2.11s	remaining: 335ms
# 864:	learn: 0.3492689	total: 2.11s	remaining: 332ms
# 865:	learn: 0.3491555	total: 2.12s	remaining: 330ms
# 866:	learn: 0.3490611	total: 2.12s	remaining: 327ms
# 867:	learn: 0.3489756	total: 2.12s	remaining: 325ms
# 868:	learn: 0.3489318	total: 2.12s	remaining: 322ms
# 869:	learn: 0.3488648	total: 2.13s	remaining: 320ms
# 870:	learn: 0.3488381	total: 2.13s	remaining: 318ms
# 871:	learn: 0.3487679	total: 2.13s	remaining: 315ms
# 872:	learn: 0.3487270	total: 2.13s	remaining: 313ms
# 873:	learn: 0.3486164	total: 2.13s	remaining: 310ms
# 874:	learn: 0.3485753	total: 2.14s	remaining: 308ms
# 875:	learn: 0.3485114	total: 2.14s	remaining: 305ms
# 876:	learn: 0.3484553	total: 2.14s	remaining: 303ms
# 877:	learn: 0.3483947	total: 2.14s	remaining: 300ms
# 878:	learn: 0.3483169	total: 2.15s	remaining: 298ms
# 879:	learn: 0.3482903	total: 2.15s	remaining: 295ms
# 880:	learn: 0.3482252	total: 2.15s	remaining: 293ms
# 881:	learn: 0.3481420	total: 2.15s	remaining: 290ms
# 882:	learn: 0.3481026	total: 2.15s	remaining: 288ms
# 883:	learn: 0.3480423	total: 2.16s	remaining: 286ms
# 884:	learn: 0.3479943	total: 2.16s	remaining: 283ms
# 885:	learn: 0.3478998	total: 2.16s	remaining: 281ms
# 886:	learn: 0.3478425	total: 2.16s	remaining: 278ms
# 887:	learn: 0.3477760	total: 2.17s	remaining: 276ms
# 888:	learn: 0.3477029	total: 2.17s	remaining: 273ms
# 889:	learn: 0.3476514	total: 2.17s	remaining: 271ms
# 890:	learn: 0.3475901	total: 2.17s	remaining: 269ms
# 891:	learn: 0.3475342	total: 2.18s	remaining: 266ms
# 892:	learn: 0.3474763	total: 2.18s	remaining: 264ms
# 893:	learn: 0.3474484	total: 2.18s	remaining: 261ms
# 894:	learn: 0.3474300	total: 2.18s	remaining: 259ms
# 895:	learn: 0.3473908	total: 2.19s	remaining: 256ms
# 896:	learn: 0.3473282	total: 2.19s	remaining: 254ms
# 897:	learn: 0.3472376	total: 2.19s	remaining: 251ms
# 898:	learn: 0.3472076	total: 2.19s	remaining: 249ms
# 899:	learn: 0.3471479	total: 2.19s	remaining: 246ms
# 900:	learn: 0.3471194	total: 2.2s	remaining: 244ms
# 901:	learn: 0.3470356	total: 2.2s	remaining: 241ms
# 902:	learn: 0.3469910	total: 2.2s	remaining: 239ms
# 903:	learn: 0.3469500	total: 2.2s	remaining: 236ms
# 904:	learn: 0.3469130	total: 2.21s	remaining: 234ms
# 905:	learn: 0.3468805	total: 2.21s	remaining: 232ms
# 906:	learn: 0.3468083	total: 2.21s	remaining: 229ms
# 907:	learn: 0.3467529	total: 2.21s	remaining: 227ms
# 908:	learn: 0.3466738	total: 2.22s	remaining: 224ms
# 909:	learn: 0.3466571	total: 2.22s	remaining: 222ms
# 910:	learn: 0.3465868	total: 2.22s	remaining: 219ms
# 911:	learn: 0.3465336	total: 2.22s	remaining: 217ms
# 912:	learn: 0.3464767	total: 2.22s	remaining: 214ms
# 913:	learn: 0.3464176	total: 2.23s	remaining: 212ms
# 914:	learn: 0.3463536	total: 2.23s	remaining: 210ms
# 915:	learn: 0.3463142	total: 2.23s	remaining: 207ms
# 916:	learn: 0.3462526	total: 2.23s	remaining: 205ms
# 917:	learn: 0.3462049	total: 2.24s	remaining: 202ms
# 918:	learn: 0.3461394	total: 2.24s	remaining: 200ms
# 919:	learn: 0.3460834	total: 2.24s	remaining: 197ms
# 920:	learn: 0.3460284	total: 2.24s	remaining: 195ms
# 921:	learn: 0.3459685	total: 2.25s	remaining: 192ms
# 922:	learn: 0.3459347	total: 2.25s	remaining: 190ms
# 923:	learn: 0.3458749	total: 2.25s	remaining: 188ms
# 924:	learn: 0.3458393	total: 2.25s	remaining: 185ms
# 925:	learn: 0.3457806	total: 2.25s	remaining: 183ms
# 926:	learn: 0.3457687	total: 2.26s	remaining: 180ms
# 927:	learn: 0.3457015	total: 2.26s	remaining: 178ms
# 928:	learn: 0.3456153	total: 2.26s	remaining: 175ms
# 929:	learn: 0.3455345	total: 2.27s	remaining: 173ms
# 930:	learn: 0.3454711	total: 2.27s	remaining: 171ms
# 931:	learn: 0.3454040	total: 2.27s	remaining: 168ms
# 932:	learn: 0.3453715	total: 2.27s	remaining: 166ms
# 933:	learn: 0.3453026	total: 2.27s	remaining: 163ms
# 934:	learn: 0.3452215	total: 2.28s	remaining: 161ms
# 935:	learn: 0.3451780	total: 2.28s	remaining: 158ms
# 936:	learn: 0.3450993	total: 2.28s	remaining: 156ms
# 937:	learn: 0.3450526	total: 2.28s	remaining: 153ms
# 938:	learn: 0.3449948	total: 2.29s	remaining: 151ms
# 939:	learn: 0.3449546	total: 2.29s	remaining: 148ms
# 940:	learn: 0.3449108	total: 2.29s	remaining: 146ms
# 941:	learn: 0.3448624	total: 2.29s	remaining: 144ms
# 942:	learn: 0.3448111	total: 2.29s	remaining: 141ms
# 943:	learn: 0.3447435	total: 2.3s	remaining: 139ms
# 944:	learn: 0.3446208	total: 2.3s	remaining: 136ms
# 945:	learn: 0.3445725	total: 2.3s	remaining: 134ms
# 946:	learn: 0.3445108	total: 2.3s	remaining: 131ms
# 947:	learn: 0.3444537	total: 2.31s	remaining: 129ms
# 948:	learn: 0.3444289	total: 2.31s	remaining: 127ms
# 949:	learn: 0.3443544	total: 2.31s	remaining: 124ms
# 950:	learn: 0.3442993	total: 2.31s	remaining: 122ms
# 951:	learn: 0.3442377	total: 2.32s	remaining: 119ms
# 952:	learn: 0.3441848	total: 2.32s	remaining: 117ms
# 953:	learn: 0.3441310	total: 2.32s	remaining: 114ms
# 954:	learn: 0.3441024	total: 2.32s	remaining: 112ms
# 955:	learn: 0.3440603	total: 2.33s	remaining: 109ms
# 956:	learn: 0.3440084	total: 2.33s	remaining: 107ms
# 957:	learn: 0.3439419	total: 2.33s	remaining: 105ms
# 958:	learn: 0.3439121	total: 2.33s	remaining: 102ms
# 959:	learn: 0.3438236	total: 2.33s	remaining: 99.7ms
# 960:	learn: 0.3437443	total: 2.34s	remaining: 97.3ms
# 961:	learn: 0.3436721	total: 2.34s	remaining: 94.9ms
# 962:	learn: 0.3436063	total: 2.34s	remaining: 92.4ms
# 963:	learn: 0.3435864	total: 2.34s	remaining: 90ms
# 964:	learn: 0.3435597	total: 2.35s	remaining: 87.6ms
# 965:	learn: 0.3434975	total: 2.35s	remaining: 85.1ms
# 966:	learn: 0.3434513	total: 2.35s	remaining: 82.7ms
# 967:	learn: 0.3433823	total: 2.35s	remaining: 80.2ms
# 968:	learn: 0.3433211	total: 2.36s	remaining: 77.8ms
# 969:	learn: 0.3432668	total: 2.36s	remaining: 75.4ms
# 970:	learn: 0.3432070	total: 2.36s	remaining: 72.9ms
# 971:	learn: 0.3431714	total: 2.36s	remaining: 70.5ms
# 972:	learn: 0.3431144	total: 2.36s	remaining: 68ms
# 973:	learn: 0.3430668	total: 2.37s	remaining: 65.6ms
# 974:	learn: 0.3430186	total: 2.37s	remaining: 63.2ms
# 975:	learn: 0.3429617	total: 2.37s	remaining: 60.7ms
# 976:	learn: 0.3429040	total: 2.37s	remaining: 58.3ms
# 977:	learn: 0.3428391	total: 2.38s	remaining: 55.9ms
# 978:	learn: 0.3428082	total: 2.38s	remaining: 53.4ms
# 979:	learn: 0.3427502	total: 2.38s	remaining: 51ms
# 980:	learn: 0.3426941	total: 2.38s	remaining: 48.6ms
# 981:	learn: 0.3426148	total: 2.38s	remaining: 46.1ms
# 982:	learn: 0.3425311	total: 2.39s	remaining: 43.7ms
# 983:	learn: 0.3425168	total: 2.39s	remaining: 41.3ms
# 984:	learn: 0.3424940	total: 2.39s	remaining: 38.8ms
# 985:	learn: 0.3423986	total: 2.39s	remaining: 36.4ms
# 986:	learn: 0.3423415	total: 2.4s	remaining: 34ms
# 987:	learn: 0.3422992	total: 2.4s	remaining: 31.6ms
# 988:	learn: 0.3422512	total: 2.4s	remaining: 29.2ms
# 989:	learn: 0.3421925	total: 2.41s	remaining: 26.8ms
# 990:	learn: 0.3421015	total: 2.41s	remaining: 24.3ms
# 991:	learn: 0.3420444	total: 2.41s	remaining: 21.9ms
# 992:	learn: 0.3419642	total: 2.42s	remaining: 19.5ms
# 993:	learn: 0.3419163	total: 2.42s	remaining: 17ms
# 994:	learn: 0.3418057	total: 2.42s	remaining: 14.6ms
# 995:	learn: 0.3417631	total: 2.42s	remaining: 12.2ms
# 996:	learn: 0.3417095	total: 2.42s	remaining: 9.73ms
# 997:	learn: 0.3416578	total: 2.43s	remaining: 7.3ms
# 998:	learn: 0.3415818	total: 2.43s	remaining: 4.86ms
# 999:	learn: 0.3415219	total: 2.43s	remaining: 2.43ms
# 1000:	learn: 0.3414812	total: 2.43s	remaining: 0us
# Registered model 'churn_model_mmakarov' already exists. Creating a new version of this model...
# 2025/03/15 12:09:28 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: churn_model_mmakarov, version 2
# Model registered at: runs:/627281a1ee9b4c8d86f3e30d0a3d16cd/models
# Created version '2' of model 'churn_model_mmakarov'.

# %%
import mlflow
import os

EXPERIMENT_NAME = "churn_mmakarov"
RUN_NAME = "m1"
REGISTRY_MODEL_NAME = "churn_model_mmakarov"


TRACKING_SERVER_HOST = "127.0.0.1"
TRACKING_SERVER_PORT = 5000

os.environ["MLFLOW_S3_ENDPOINT_URL"] = "https://storage.yandexcloud.net"
os.environ['AWS_ACCESS_KEY_ID'] = os.getenv('S3_ACCESS_KEY')
os.environ['AWS_SECRET_ACCESS_KEY'] = os.getenv('S3_SECRET_KEY')

mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}")
mlflow.set_registry_uri(f"http://{TRACKING_SERVER_HOST}:{TRACKING_SERVER_PORT}")
mlflow.set_experiment("churn_mmakarov")

client = mlflow.MlflowClient() 

models = client.search_model_versions(
    filter_string=f"name = '{REGISTRY_MODEL_NAME}'"
)

print(f"Model info:\n {models}")

model_name_1 = models[-1].name
model_version_1 = models[-1].version
model_stage_1 = models[-1].current_stage

model_name_2 = models[-2].name
model_version_2 = models[-2].version
model_stage_2 = models[-2].current_stage


print(f"Текущий stage модели 1: {model_stage_1}")
print(f"Текущий stage модели 2: {model_stage_2}")

# Поменяйте статус каждой модели

client.transition_model_version_stage(model_name_1, model_version_1, 'production')
client.transition_model_version_stage(model_name_2, model_version_2, 'staging')
# Переименуйте модель в реестре

client.rename_registered_model(name=REGISTRY_MODEL_NAME, new_name=f'{REGISTRY_MODEL_NAME}_b2c')
